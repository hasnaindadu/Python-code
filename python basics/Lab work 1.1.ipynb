# %%
#Q-3 To print in multiple lines
#method 1 using \n
print("hello world\nhiii")

#method 2 using triple double quotes""" or single '''
print("""hello world
myname is hasnain""")

print("*\n**\n***\n**\n*")
# Out:
# hello world
# hiii
# hello world
# myname is hasnain
# *
# **
# ***
# **
# *
