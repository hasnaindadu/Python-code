# %%
print("Hello!! and welcome to data collection programme!")
print("*****************************************")
print(end =" ")
name = input("Please enter your Name:-")
age = int(input("Please enter your Age:-"))
height = float(input("Please enter your Height:-"))
fav_number = int(input("Please enter your Favourite Number:-"))
print("*****************************************")
print("Thank you!! We appriciate your patiance")
print("*****************************************")
print(end =" ")
print("Name:",name,"type:-",type(name),"Memory Address:-",id(name))
print("Age:",age,"type:-",type(age),"Memory Address:-",id(age))
print("Height:",height,"type:-",type(height),"Memory Address:-",id(height))
print("Height:",fav_number,"type:-",type(fav_number),"Memory Address:-",id(fav_number))
print("*****************************************")
print("Your Birth year is Approximately:-",2025-age,"(as per your birth year)")
print("*****************************************")
print(end =" ")
print("Thank you for your support!! visit again.")
print("*****************************************")
# Out:
# Hello!! and welcome to data collection programme!
# *****************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5714d7b27b60> in <cell line: 0>()
#       2 print("*****************************************")
#       3 print(end =" ")
# ----> 4 name = input("Please enter your Name:-")
#       5 age = int(input("Please enter your Age:-"))
#       6 height = float(input("Please enter your Height:-"))
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...
